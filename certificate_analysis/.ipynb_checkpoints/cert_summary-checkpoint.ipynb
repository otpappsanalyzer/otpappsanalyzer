# %%
import pandas as pd
cert_path = '/home/budi/OTP_project/OTP_code/certificate_analysis/apksigner_extraction.csv'

cert_df = pd.read_csv(cert_path)
cert_df
# Out:
#                                   app_id key_algorithm  key_size version1  \
# 0               com.hpe.icewall.smartotp           RSA      2048     True
# 1                        com.securekiotp           RSA      2048     True
# 2                     com.nhn.hangameotp           RSA      2048     True
# 3                        de.sbeh.rdp_otp           RSA      4096     True
# 4                 sg.worktable.pingoauth           RSA      2048     True
# ..                                   ...           ...       ...      ...
# 177   com.mastersam.android.mastersamotp           RSA      2048     True
# 178         br.com.powersoftware.otpsafe           RSA      4096     True
# 179  hr.asseco.android.jimba.otpretailng           DSA      1024     True
# 180                   kr.kjun.NaverSetup           RSA      2048     True
# 181             com.netfiles.netfilesotp           RSA      1024     True
#
#     version2 version3  protected
# 0      False    False      False
# ...

# %%
v1_df = cert_df[cert_df['version1']=='True']
v1_df
# Out:
# Empty DataFrame
# Columns: [app_id, key_algorithm, key_size, version1, version2, version3, protected]
# Index: []
